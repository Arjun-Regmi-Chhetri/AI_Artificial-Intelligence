# %%
# !pip install opencv-python

# %%
#libraries

import cv2 
import numpy as np
from matplotlib import pyplot as plt

# %%
# load color image in grayscale
img = cv2.imread('sun.jpg')

plt.imshow(img)

# %%
row, col, channels=img.shape

print(f"row = {row},\ncol = {col},\nchannels = {channels}")

print(img)
# Out:
# row = 360,
# col = 360,
# channels = 3
# [[[234 233 205]
#   [232 231 203]
#   [228 227 199]
#   ...
#   [255 254 250]
#   [255 254 250]
#   [255 254 250]]
#
#  [[236 235 207]
#   [234 233 205]
#   [231 230 202]
#   ...
#   [255 254 250]
#   [255 254 250]
#   [255 254 250]]
#
#  [[239 238 212]
#   [237 236 210]
#   [234 233 207]
#   ...
#   [255 254 250]
#   [255 254 250]
#   [255 254 250]]
#
#  ...
#
#  [[ 29  67  45]
#   [ 31  69  47]
#   [ 33  72  51]
#   ...
#   [ 43  90  57]
#   [ 43  90  57]
#   [ 43  90  57]]
#
#  [[ 30  68  46]
#   [ 32  70  48]
#   [ 33  72  50]
#   ...
#   [ 43  90  57]
#   [ 43  91  55]
#   [ 43  91  55]]
#
#  [[ 30  68  46]
#   [ 32  70  48]
#   [ 33  72  50]
#   ...
#   [ 43  90  57]
#   [ 43  91  55]
#   [ 43  91  55]]]

# %%
plt.matshow(img)

# %%
plt.imshow(img, cmap='gray')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
# lodaing original image
import matplotlib.image as mpimg # for reading images

image = mpimg.imread('sun.jpg')
print('Image Dimension :', image.shape)

plt.xticks([]), plt.yticks([])

plt.imshow(image)
# Out:
# Image Dimension : (360, 360, 3)

# %%
print(image)
# Out:
# [[[205 233 234]
#   [203 231 232]
#   [199 227 228]
#   ...
#   [250 254 255]
#   [250 254 255]
#   [250 254 255]]
#
#  [[207 235 236]
#   [205 233 234]
#   [202 230 231]
#   ...
#   [250 254 255]
#   [250 254 255]
#   [250 254 255]]
#
#  [[212 238 239]
#   [210 236 237]
#   [207 233 234]
#   ...
#   [250 254 255]
#   [250 254 255]
#   [250 254 255]]
#
#  ...
#
#  [[ 45  67  29]
#   [ 47  69  31]
#   [ 51  72  33]
#   ...
#   [ 57  90  43]
#   [ 57  90  43]
#   [ 57  90  43]]
#
#  [[ 46  68  30]
#   [ 48  70  32]
#   [ 50  72  33]
#   ...
#   [ 57  90  43]
#   [ 55  91  43]
#   [ 55  91  43]]
#
#  [[ 46  68  30]
#   [ 48  70  32]
#   [ 50  72  33]
#   ...
#   [ 57  90  43]
#   [ 55  91  43]
#   [ 55  91  43]]]

# %%
img = cv2.imread('sun.jpg', 1)
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(gray_image, cmap='gray')

plt.title('Original Image')
plt.xticks([]), plt.yticks([])

plt.show()

print(gray_image.shape)
print(img.shape)
# Out:
# (360, 360)
# (360, 360, 3)

# %%
print(gray_image)
# Out:
# [[225 223 219 ... 253 253 253]
#  [227 225 222 ... 253 253 253]
#  [230 228 225 ... 253 253 253]
#  ...
#  [ 56  58  61 ...  75  75  75]
#  [ 57  59  61 ...  75  75  75]
#  [ 57  59  61 ...  75  75  75]]

# %%
# to show pixelgrid use matshow

plt.matshow(gray_image, cmap='gray')

# %%
#create 5*5 image using just grayscale, numerical values

tiny_image = np.array([
    [10,20,30,40,50],
    [5,15,25,35,45],
    [60,70,80,90,100],
    [55,65,75,85,95],
    [47,57,67,77,87]
])

# to show the pixel grid, use matshow
plt.matshow(tiny_image, cmap='gray')

# %%
# Create a 5x5 image using just grayscale, numerical values
tiny_image = np.array([[0,255,0,255,0,255,0,255],
                      [255,0,255,0,255,0,255,0],
                      [0,255,0,255,0,255,0,255],
                      [255,0,255,0,255,0,255,0],
                      [0,255,0,255,0,255,0,255]])


# to show pixel grid, use matshow

plt.matshow(tiny_image, cmap='gray')

# %%
# Create a 5x5 image using just grayscale, numerical values
tiny_image = np.array([[0,255,0,255,0,255,0,255],
                      [0,255,0,255,0,255,0,255],
                      [0,255,0,255,0,255,0,255],
                      [0,255,0,255,0,255,0,255],
                      [0,255,0,255,0,255,0,255]])

#to show the pixel grid, use matshow
plt.matshow(tiny_image, cmap='gray')

# %%
# Create a 5x5 image using just grayscale, numerical values
tiny_image = np.array([[[45,45,45], [0,255,255], [0,255,0]]])

#to show the pixel grid, use matshow
plt.matshow(tiny_image)

# %%
# Load the image in grayscale
img = cv2.imread('sun.jpg', 1)
plt.imshow(img)

# %%
#Isolate RGB channels
img = cv2.imread('sun.jpg', 1)

r= img[:, :, 0]
g = img[:, :, 1]
b = img[:, :, 2]

#visualize the individual color channels
f, (ax1, ax2, ax3) = plt.subplots(1, 3 ,figsize=(20,10))

ax1.set_title('R-Channel')
ax1.imshow(r, cmap='gray')

ax2.set_title('G-Channel')
ax2.imshow(g, cmap='gray')

ax3.set_title('B-Channel')
ax3.imshow(b, cmap='gray')

# %%
#Isolate RGB channels

r = img[:,:, 0]
g = img[:,:,1]
b = img[:,:,2]

# visualize the individual color channels

f, (ax1, ax2, ax3) = plt.subplots(1, 3 , figsize=(15,5))

ax1.set_title('R-Channel')
ax1.imshow(r)

ax2.set_title('G-Channel')
ax2.imshow(g)

ax3.set_title('B-Channel')
ax3.imshow(b)
